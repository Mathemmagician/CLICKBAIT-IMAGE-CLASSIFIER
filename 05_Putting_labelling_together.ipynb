# %% [markdown]
# # Part 5
# Goals:
# 1. Put together all the functions
# 2. Test labelling

# %%
import pandas as pd
from matplotlib import pyplot as plt
from IPython.display import display, Image
from pigeon import annotate
import random

random.seed(82)
# %matplotlib inline

# %%
# df = pd.read_pickle("./df_no_img_no_labels.pkl")   # if no labels
# df = pd.read_pickle("./data/df_partial_labels.pkl")  # if already labelled before

# %%
df.head()
# Out:
#       video_id label
# 0  J_CFBjAyPWE  None
# 1  5qxqo2CQakA  None
# 2  4Syrtc5aRBY  None
# 3  1mpdJcGj8Qg  None
# 4  coOKvrsmQiI  None

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5962 entries, 0 to 5961
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   video_id  5962 non-null   object
#  1   label     0 non-null      object
# dtypes: object(2)
# memory usage: 93.3+ KB

# %%
def generate_labels(df, n=5):
    # n is the number of how many you want to label
    ids = df[df['label'].isna()][:n]['video_id']

    annotations = annotate(
      ids,
      options=['Clickbait', 'Not_Clickbait', 'Maybe'],
      display_fn=lambda filename: display(Image(f'data/imgs/{filename}.jpg'))
    )

    return annotations

# %%
def apply_labels_and_save(df, annotations):
    # This takes in the array of tuples generated by generate_labels() and applies the 
    # pandas magic to merge new labels into our df
    
    df['label'] = df['video_id'].map(dict(annotations)).fillna(df['label'])
    df.to_pickle("./data/df_partial_labels.pkl")

# %% [markdown]
#  FOR SOME REASON I CAN'T REFER TO generate_labels() inside the function. So to do labelling I'll need to run the cell below
#
#  There is some widget magic happening together with jupyter magic which doesn't let me to first compute
# annotations and then return it

# %%
# ====== RUN THIS CELL TO GENERATE LABELS ==========
ans = generate_labels(df) #, n=100)
# Out:
# HTML(value='0 examples annotated, 6 examples left')
# ...
# Output()
# Annotation done.

# %%
apply_labels_and_save(df, ans)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5962 entries, 0 to 5961
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   video_id  5962 non-null   object
#  1   label     10 non-null     object
# dtypes: object(2)
# memory usage: 93.3+ KB

# %%
test = pd.read_pickle("./data/df_partial_labels.pkl")

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5962 entries, 0 to 5961
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   video_id  5962 non-null   object
#  1   label     10 non-null     object
# dtypes: object(2)
# memory usage: 93.3+ KB

# %% [markdown]
#  Even though this is the shortest notebook, the amount of time spent on figuring out
#  how pigeion.annotate() works in functions wasted a lot of time.
#  good new is that now we have a working annotate() function, which we can use to label our data set
#
# What does this mean?
# # THAT WE CAN NOW DO MACHINE LEARNING
# (right after we actually go through our ........... 6000....... manual.... oh no
